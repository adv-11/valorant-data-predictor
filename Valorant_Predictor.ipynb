# %% [markdown]
# <a href="https://colab.research.google.com/github/adv-11/valorant-data-predictor/blob/main/Valorant_Predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
userName= ""
userId=""
userName = input('Enter Valorant Username : ')
userId = input('Enter Valorant ID (dont include #) : ')
# Out:
# Enter Valorant Username : adv
# Enter Valorant ID (dont include #) : 7097

# %%
puuid_url = "https://api.henrikdev.xyz/valorant/v1/account/"+userName+"/"+userId
resp_puuid = requests.get(puuid_url)
data_puuid = resp_puuid.json()
resp_puuid.json()
# Out:
# {'status': 200,
#  'data': {'puuid': 'b62a1bff-f866-5577-a07a-7d5d9831bc3d',
#   'region': 'ap',
#   'account_level': 149,
#   'name': 'adv',
#   'tag': '7097',
#   'card': {'small': 'https://media.valorant-api.com/playercards/7a7571d2-452f-ce65-0ae3-4f95b09ee92e/smallart.png',
#    'large': 'https://media.valorant-api.com/playercards/7a7571d2-452f-ce65-0ae3-4f95b09ee92e/largeart.png',
#    'wide': 'https://media.valorant-api.com/playercards/7a7571d2-452f-ce65-0ae3-4f95b09ee92e/wideart.png',
#    'id': '7a7571d2-452f-ce65-0ae3-4f95b09ee92e'},
#   'last_update': 'Now',
#   'last_update_raw': 1706611128}}

# %%
puuid = data_puuid['data']['puuid']

comp_data_api = ""
comp_data_api = "https://api.henrikdev.xyz/valorant/v1/by-puuid/lifetime/matches/eu/"+puuid+"?mode=competitive"
comp_data_api_2 = "https://api.henrikdev.xyz/valorant/v1/lifetime/matches/ap/"+userName+"/"+userId+"?mode=competitive"
print(comp_data_api)
# Out:
# https://api.henrikdev.xyz/valorant/v1/by-puuid/lifetime/matches/eu/b62a1bff-f866-5577-a07a-7d5d9831bc3d?mode=competitive

# %%
resp_comp = requests.get(comp_data_api_2)
comp_data = resp_comp.json()

# %%
matches_data = comp_data.get('data', [])
df = pd.json_normalize(matches_data)
df
# Out:
#                                  meta.id  \
# 0   84be33b4-04ff-4f82-8850-4a579a4c5063
# 1   e54ddbb7-282a-4018-8b1a-6d67f6fcff64
# 2   7aeecb64-1e01-4744-92d5-c947a8951401
# 3   42cbefae-acf5-4bc8-9824-0152c4045a8c
# 4   ba8a861a-ce90-4918-b96a-de57f73059b0
# 5   058bc978-7ae7-4554-b248-6561b3e8adb4
# 6   012ae9f8-9564-4a7b-80ed-7c4dab9223b1
# 7   330d17ed-455c-4003-bfb3-332951865ae8
# 8   1489cb6c-1baa-4d56-913b-3fb4a7ecf352
# 9   df59f5f2-eddf-423f-b3f4-a1ba4eb163ce
# 10  283a2dcf-593e-4832-af51-e69cbd91d9e5
# 11  dadd7405-fb0c-4689-b9fb-c6e8ba48127b
# 12  08f2c021-b537-4f65-b9ab-e3e25cdc99e5
# 13  c5b5b75b-0df7-4586-9d9f-4abec4e543cd
# 14  c6c318a6-e6eb-483b-83cb-03562282b1ec
# 15  9b2fcc43-7f23-485f-9f7b-9cd1e54e622a
# 16  2b6cddc5-9562-4bef-a413-46733629c91a
# 17  49e4825c-d9e2-4d0b-bcd8-c0863ab18c56
# 18  47e5f070-4a10-49c2-b813-8ce9fae43f51
# 19  b88c0c5b-fc1b-4bf4-9b8f-ec3aba49864c
# 20  5160444d-48fb-49af-a4e2-1d3bbebcccf5
# 21  2dc948bf-1e9e-4607-bc5e-90c357c7d147
# 22  2b1a9075-7717-496f-ad32-5844df376ae1
# 23  9c82e305-2f8e-46b1-9c25-1d726753eb16
# 24  4b282add-6388-4913-9020-bf47a0df8fb5
#
#                              meta.map.id meta.map.name  \
# 0   2fe4ed3a-450a-948b-6d6b-e89a78e680a9         Lotus
# 1   7eaecc1b-4337-bbf6-6ab9-04b8f06b3319        Ascent
# 2   7eaecc1b-4337-bbf6-6ab9-04b8f06b3319        Ascent
# 3   e2ad5c54-4114-a870-9641-8ea21279579a        Icebox
# 4   d960549e-485c-e861-8d71-aa9d1aed12a2         Split
# 5   2fe4ed3a-450a-948b-6d6b-e89a78e680a9         Lotus
# 6   2fb9a4fd-47b8-4e7d-a969-74b4046ebd53        Breeze
# 7   92584fbe-486a-b1b2-9faa-39b0f486b498        Sunset
# 8   2c9d57ec-4431-9c5e-2939-8f9ef6dd5cba          Bind
# 9   e2ad5c54-4114-a870-9641-8ea21279579a        Icebox
# 10  e2ad5c54-4114-a870-9641-8ea21279579a        Icebox
# 11  d960549e-485c-e861-8d71-aa9d1aed12a2         Split
# 12  2fe4ed3a-450a-948b-6d6b-e89a78e680a9         Lotus
# 13  2c9d57ec-4431-9c5e-2939-8f9ef6dd5cba          Bind
# 14  7eaecc1b-4337-bbf6-6ab9-04b8f06b3319        Ascent
# 15  e2ad5c54-4114-a870-9641-8ea21279579a        Icebox
# 16  d960549e-485c-e861-8d71-aa9d1aed12a2         Split
# 17  7eaecc1b-4337-bbf6-6ab9-04b8f06b3319        Ascent
# 18  2c9d57ec-4431-9c5e-2939-8f9ef6dd5cba          Bind
# 19  2c9d57ec-4431-9c5e-2939-8f9ef6dd5cba          Bind
# 20  d960549e-485c-e861-8d71-aa9d1aed12a2         Split
# 21  e2ad5c54-4114-a870-9641-8ea21279579a        Icebox
# 22  e2ad5c54-4114-a870-9641-8ea21279579a        Icebox
# 23  2fe4ed3a-450a-948b-6d6b-e89a78e680a9         Lotus
# 24  7eaecc1b-4337-bbf6-6ab9-04b8f06b3319        Ascent
#
#                          meta.version    meta.mode           meta.started_at  \
# 0    release-08.01-shipping-4-2228372  Competitive  2024-01-30T10:04:09.586Z
# 1    release-08.01-shipping-4-2228372  Competitive  2024-01-29T09:32:35.115Z
# 2    release-08.01-shipping-4-2228372  Competitive  2024-01-28T15:53:41.941Z
# 3    release-08.01-shipping-4-2228372  Competitive  2024-01-28T10:27:58.623Z
# 4    release-08.01-shipping-4-2228372  Competitive  2024-01-28T09:35:48.667Z
# 5    release-08.01-shipping-4-2228372  Competitive  2024-01-28T08:56:17.752Z
# 6    release-08.01-shipping-4-2228372  Competitive  2024-01-27T15:46:15.604Z
# 7    release-08.01-shipping-4-2228372  Competitive  2024-01-27T10:38:39.562Z
# 8    release-08.01-shipping-4-2228372  Competitive  2024-01-27T08:46:03.459Z
# 9    release-08.01-shipping-4-2228372  Competitive  2024-01-27T08:09:59.243Z
# 10   release-08.01-shipping-4-2228372  Competitive  2024-01-27T07:24:21.528Z
# 11   release-08.01-shipping-4-2228372  Competitive  2024-01-26T09:27:28.906Z
# 12   release-08.01-shipping-4-2228372  Competitive  2024-01-26T08:41:03.446Z
# 13   release-08.01-shipping-4-2228372  Competitive  2024-01-24T09:11:00.108Z
# 14   release-08.01-shipping-4-2228372  Competitive  2024-01-24T08:29:09.245Z
# 15   release-08.01-shipping-4-2228372  Competitive  2024-01-24T06:51:31.490Z
# 16  release-08.00-shipping-14-2191955  Competitive  2024-01-22T09:07:32.511Z
# 17  release-08.00-shipping-14-2191955  Competitive  2024-01-22T07:41:10.203Z
# 18  release-08.00-shipping-14-2191955  Competitive  2024-01-21T15:47:00.802Z
# 19  release-08.00-shipping-14-2191955  Competitive  2024-01-21T11:28:38.333Z
# 20  release-08.00-shipping-14-2191955  Competitive  2024-01-21T10:54:44.398Z
# 21  release-08.00-shipping-14-2191955  Competitive  2024-01-21T10:15:00.875Z
# 22  release-08.00-shipping-14-2191955  Competitive  2024-01-21T07:24:39.253Z
# 23   release-07.03-shipping-11-953184  Competitive  2023-08-16T15:48:02.900Z
# 24   release-05.10-shipping-11-796984  Competitive  2022-11-26T05:57:43.899Z
#
#                           meta.season.id meta.season.short meta.region  \
# 0   ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 1   ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 2   ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 3   ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 4   ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 5   ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 6   ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 7   ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 8   ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 9   ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 10  ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 11  ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 12  ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 13  ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 14  ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 15  ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 16  ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 17  ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 18  ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 19  ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 20  ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 21  ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 22  ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 23  0981a882-4e7d-371a-70c4-c3b4f46c504a              e7a1          ap
# 24  aca29595-40e4-01f5-3f35-b1b3d304c96e              e5a3        None
#
#    meta.cluster  ... stats.kills stats.deaths  stats.assists stats.shots.head  \
# 0        Mumbai  ...          16            9              5                7
# 1        Mumbai  ...          22            6             14                5
# 2        Mumbai  ...           7           14              5                5
# 3        Mumbai  ...          16           16              5                9
# 4        Mumbai  ...          14           17             10                4
# 5        Mumbai  ...          10           13              4                5
# 6        Mumbai  ...           7           17              2                7
# 7        Mumbai  ...          12           14              4                9
# 8        Mumbai  ...          11           20              6                5
# 9        Mumbai  ...          19           15              5                9
# 10       Mumbai  ...          14           18              4                7
# 11       Mumbai  ...          16           10             12                4
# 12       Mumbai  ...          19           16             10               13
# 13       Mumbai  ...          14            8             13                8
# 14       Mumbai  ...          10           14              4                6
# 15       Mumbai  ...          15           17             15                7
# 16       Mumbai  ...           9           15              7               11
# 17       Mumbai  ...          17           19             17                7
# 18       Mumbai  ...          12           14              9                4
# 19       Mumbai  ...           9           19             11                3
# 20       Mumbai  ...           9           14              9                5
# 21       Mumbai  ...          13            9              2                5
# 22       Mumbai  ...          22           23              7               12
# 23       Mumbai  ...          14           16              7                5
# 24       Mumbai  ...          22           20              8               11
#
#    stats.shots.body  stats.shots.leg  stats.damage.made  \
# 0                47                8               2577
# 1                70                7               3588
# 2                28               10               2062
# 3                47               12               2821
# 4                62               22               2774
# 5                39               14               2292
# 6                42                5               1611
# 7                45               16               2096
# 8                45               25               2339
# 9                62               38               3426
# 10               66               13               2683
# 11               41               13               2447
# 12               56               16               3870
# 13               56                9               2174
# 14               33               13               1924
# 15               71               18               2908
# 16               37               17               2264
# 17               50               16               3595
# 18               90                9               2727
# 19               46               11               2055
# 20               26               10               1944
# 21               64                4               2362
# 22               95               27               4417
# 23               64                8               2754
# 24               90               20               4096
#
#     stats.damage.received  teams.red  teams.blue
# 0                    1578         13           5
# 1                    1748          5          13
# 2                    2377          3          13
# 3                    3404          7          13
# 4                    3163          9          13
# 5                    2137          8          13
# 6                    2602         13           8
# 7                    2421         13           5
# 8                    3433         16          14
# 9                    2643         13           7
# 10                   3002         13          10
# 11                   2189          8          13
# 12                   2999         11          13
# 13                   2073         13           4
# 14                   2664         13          10
# 15                   3011          8          13
# 16                   2449         13           5
# 17                   3319         14          12
# 18                   2567         13          11
# 19                   3545          9          13
# 20                   2430         13           5
# 21                   1775         13           8
# 22                   4422         16          14
# 23                   3451         10          13
# 24                   3511         13          10
#
# [25 rows x 27 columns]

# %%
columns_to_drop = ['meta.map.id', 'meta.id', 'meta.version','meta.started_at' , 'meta.season.id' , 'meta.season.short' , 'stats.character.id' , 'stats.puuid' , 'stats.tier']
df = df.drop(columns=columns_to_drop, errors='ignore')

def determine_win(row):
  if (row['stats.team'] == 'Red') and (row['teams.red'] > row['teams.blue'])  :
     return('won')

  if (row['stats.team'] == 'Blue') and (row['teams.red'] < row['teams.blue']) :
     return('won')

  else : return('lost')

df['stats.win']=df.apply(determine_win , axis=1)
df
# Out:
#    meta.map.name    meta.mode meta.region meta.cluster stats.team  \
# 0          Lotus  Competitive          ap       Mumbai        Red
# 1         Ascent  Competitive          ap       Mumbai       Blue
# 2         Ascent  Competitive          ap       Mumbai        Red
# 3         Icebox  Competitive          ap       Mumbai        Red
# 4          Split  Competitive          ap       Mumbai        Red
# 5          Lotus  Competitive          ap       Mumbai        Red
# 6         Breeze  Competitive          ap       Mumbai       Blue
# 7         Sunset  Competitive          ap       Mumbai       Blue
# 8           Bind  Competitive          ap       Mumbai       Blue
# 9         Icebox  Competitive          ap       Mumbai       Blue
# 10        Icebox  Competitive          ap       Mumbai        Red
# 11         Split  Competitive          ap       Mumbai       Blue
# 12         Lotus  Competitive          ap       Mumbai        Red
# 13          Bind  Competitive          ap       Mumbai        Red
# 14        Ascent  Competitive          ap       Mumbai        Red
# 15        Icebox  Competitive          ap       Mumbai        Red
# 16         Split  Competitive          ap       Mumbai       Blue
# 17        Ascent  Competitive          ap       Mumbai        Red
# 18          Bind  Competitive          ap       Mumbai        Red
# 19          Bind  Competitive          ap       Mumbai        Red
# 20         Split  Competitive          ap       Mumbai       Blue
# 21        Icebox  Competitive          ap       Mumbai        Red
# 22        Icebox  Competitive          ap       Mumbai       Blue
# 23         Lotus  Competitive          ap       Mumbai       Blue
# 24        Ascent  Competitive        None       Mumbai       Blue
#
#     stats.level stats.character.name  stats.score  stats.kills  stats.deaths  \
# 0           149            Brimstone         3892           16             9
# 1           149            Brimstone         5853           22             6
# 2           148                 Sova         2778            7            14
# 3           148                Reyna         4256           16            16
# 4           148            Brimstone         4158           14            17
# 5           148               Breach         3245           10            13
# 6           148              Killjoy         2319            7            17
# 7           148            Brimstone         3531           12            14
# 8           147            Brimstone         3546           11            20
# 9           147                 Omen         5458           19            15
# 10          147              Killjoy         3922           14            18
# 11          146            Brimstone         4153           16            10
# 12          146            Brimstone         5653           19            16
# 13          146            Brimstone         3876           14             8
# 14          146                 Sova         2680           10            14
# 15          146            Brimstone         4779           15            17
# 16          146            Brimstone         3157            9            15
# 17          145            Brimstone         5428           17            19
# 18          145              Killjoy         3890           12            14
# 19          145            Brimstone         3215            9            19
# 20          145            Brimstone         3119            9            14
# 21          145              Killjoy         3811           13             9
# 22          145              Killjoy         6270           22            23
# 23          109                Gekko         4123           14            16
# 24           23                 Yoru         6442           22            20
#
#     stats.assists  stats.shots.head  stats.shots.body  stats.shots.leg  \
# 0               5                 7                47                8
# 1              14                 5                70                7
# 2               5                 5                28               10
# 3               5                 9                47               12
# 4              10                 4                62               22
# 5               4                 5                39               14
# 6               2                 7                42                5
# 7               4                 9                45               16
# 8               6                 5                45               25
# 9               5                 9                62               38
# 10              4                 7                66               13
# 11             12                 4                41               13
# 12             10                13                56               16
# 13             13                 8                56                9
# 14              4                 6                33               13
# 15             15                 7                71               18
# 16              7                11                37               17
# 17             17                 7                50               16
# 18              9                 4                90                9
# 19             11                 3                46               11
# 20              9                 5                26               10
# 21              2                 5                64                4
# 22              7                12                95               27
# 23              7                 5                64                8
# 24              8                11                90               20
#
#     stats.damage.made  stats.damage.received  teams.red  teams.blue stats.win
# 0                2577                   1578         13           5       won
# 1                3588                   1748          5          13       won
# 2                2062                   2377          3          13      lost
# 3                2821                   3404          7          13      lost
# 4                2774                   3163          9          13      lost
# 5                2292                   2137          8          13      lost
# 6                1611                   2602         13           8      lost
# 7                2096                   2421         13           5      lost
# 8                2339                   3433         16          14      lost
# 9                3426                   2643         13           7      lost
# 10               2683                   3002         13          10       won
# 11               2447                   2189          8          13       won
# 12               3870                   2999         11          13      lost
# 13               2174                   2073         13           4       won
# 14               1924                   2664         13          10       won
# 15               2908                   3011          8          13      lost
# 16               2264                   2449         13           5      lost
# 17               3595                   3319         14          12       won
# 18               2727                   2567         13          11       won
# 19               2055                   3545          9          13      lost
# 20               1944                   2430         13           5      lost
# 21               2362                   1775         13           8       won
# 22               4417                   4422         16          14      lost
# 23               2754                   3451         10          13       won
# 24               4096                   3511         13          10      lost

# %%
from matplotlib import pyplot as plt
df['stats.kills'].plot(kind='line', figsize=(8, 4), title='stats.kills')
# Out:
# <Axes: title={'center': 'stats.kills'}>

# %%
from matplotlib import pyplot as plt
import seaborn as sns

def determine_color(row):
    return 'green' if row['stats.win'] == 'won' else 'red'

# Add a new column 'bar_color' based on stats.win
df['bar_color'] = df.apply(determine_color, axis=1)

# Plotting the bar graph
plt.figure(figsize=(10, 6))
ax = sns.countplot(y='stats.character.name', hue='bar_color', data=df, palette={'red': 'red', 'green': 'green'})
ax.set(xlabel='Frequency', ylabel='Character')
plt.title('Character Frequency and Win/Loss')
plt.gca().spines[['top', 'right']].set_visible(False)
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder

# Assuming df is your DataFrame

# Select relevant columns
selected_columns = ['meta.map.name', 'stats.character.name', 'stats.win']

# Create a new DataFrame with selected columns
df_model = df[selected_columns]

# Encode categorical variables
le_map = LabelEncoder()
le_character = LabelEncoder()

df_model['map_encoded'] = le_map.fit_transform(df_model['meta.map.name'])
df_model['character_encoded'] = le_character.fit_transform(df_model['stats.character.name'])

# Split data into features and target variable
X = df_model[['map_encoded', 'character_encoded']]
y = df_model['stats.win']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# Create a logistic regression model
model = LogisticRegression()

# Train the model
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Combine the test set and predictions


df_results = pd.DataFrame({'map': le_map.inverse_transform(X_test['map_encoded']),
                            'character': le_character.inverse_transform(X_test['character_encoded']),
                            'actual_win': y_test,
                            'predicted_win': y_pred})

df_results['actual_win'] = df_results['actual_win'].map({'lost': 0, 'won': 1})

# Calculate win rates for each character on each map
win_rate_df = df_results.groupby(['map', 'character']).agg({'actual_win': 'mean'}).reset_index()

# Display the results
print(win_rate_df)
# Out:
#      map  character  actual_win
# 0   Bind  Brimstone         0.0
# 1  Lotus  Brimstone         1.0
# 2  Split  Brimstone         0.0
# <ipython-input-10-9fa5658c3127>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['map_encoded'] = le_map.fit_transform(df_model['meta.map.name'])
# <ipython-input-10-9fa5658c3127>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['character_encoded'] = le_character.fit_transform(df_model['stats.character.name'])

# %%
df['accuracy_head'] = df['stats.shots.head'] * 100 / (df['stats.shots.head'] + df['stats.shots.body'] + df['stats.shots.leg'])
df['accuracy_body'] = df['stats.shots.body'] * 100 / (df['stats.shots.head'] + df['stats.shots.body'] + df['stats.shots.leg'])
df['accuracy_leg'] = df['stats.shots.leg'] * 100 / (df['stats.shots.head'] + df['stats.shots.body'] + df['stats.shots.leg'])

# Create a bar chart
fig, ax = plt.subplots(figsize=(10, 6))

# Plot accuracy for head, body, and leg shots
df[['accuracy_head', 'accuracy_body', 'accuracy_leg']].mean().plot(kind='bar', color=['red', 'green', 'orange'], ax=ax)

# Add labels and title
plt.title('Accuracy by Shot Type')

plt.ylabel('Accuracy in %')

# Display the plot
plt.show()
