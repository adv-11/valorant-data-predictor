# %% [markdown]
# <a href="https://colab.research.google.com/github/adv-11/valorant-data-predictor/blob/main/Valorant_Predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
userName= ""
userId=""
userName = input('Enter Valorant Username : ')
userId = input('Enter Valorant ID (dont include #) : ')
# Out:
# Enter Valorant Username : adv
# Enter Valorant ID (dont include #) : 7097

# %%
puuid_url = "https://api.henrikdev.xyz/valorant/v1/account/"+userName+"/"+userId
resp_puuid = requests.get(puuid_url)
data_puuid = resp_puuid.json()
resp_puuid.json()
# Out:
# {'status': 200,
#  'data': {'puuid': 'b62a1bff-f866-5577-a07a-7d5d9831bc3d',
#   'region': 'ap',
#   'account_level': 146,
#   'name': 'adv',
#   'tag': '7097',
#   'card': {'small': 'https://media.valorant-api.com/playercards/7a7571d2-452f-ce65-0ae3-4f95b09ee92e/smallart.png',
#    'large': 'https://media.valorant-api.com/playercards/7a7571d2-452f-ce65-0ae3-4f95b09ee92e/largeart.png',
#    'wide': 'https://media.valorant-api.com/playercards/7a7571d2-452f-ce65-0ae3-4f95b09ee92e/wideart.png',
#    'id': '7a7571d2-452f-ce65-0ae3-4f95b09ee92e'},
#   'last_update': 'Now',
#   'last_update_raw': 1706245139}}

# %%
puuid = data_puuid['data']['puuid']

comp_data_api = ""
comp_data_api = "https://api.henrikdev.xyz/valorant/v1/by-puuid/lifetime/matches/eu/"+puuid+"?mode=competitive"
print(comp_data_api)
# Out:
# https://api.henrikdev.xyz/valorant/v1/by-puuid/lifetime/matches/eu/b62a1bff-f866-5577-a07a-7d5d9831bc3d?mode=competitive

# %%
resp_comp = requests.get(comp_data_api)
comp_data = resp_comp.json()

# %%
matches_data = comp_data.get('data', [])
df = pd.json_normalize(matches_data)
df
# Out:
#                                  meta.id  \
# 0   c5b5b75b-0df7-4586-9d9f-4abec4e543cd
# 1   c6c318a6-e6eb-483b-83cb-03562282b1ec
# 2   9b2fcc43-7f23-485f-9f7b-9cd1e54e622a
# 3   2b6cddc5-9562-4bef-a413-46733629c91a
# 4   49e4825c-d9e2-4d0b-bcd8-c0863ab18c56
# 5   47e5f070-4a10-49c2-b813-8ce9fae43f51
# 6   b88c0c5b-fc1b-4bf4-9b8f-ec3aba49864c
# 7   5160444d-48fb-49af-a4e2-1d3bbebcccf5
# 8   2dc948bf-1e9e-4607-bc5e-90c357c7d147
# 9   2b1a9075-7717-496f-ad32-5844df376ae1
# 10  9c82e305-2f8e-46b1-9c25-1d726753eb16
# 11  4b282add-6388-4913-9020-bf47a0df8fb5
#
#                              meta.map.id meta.map.name  \
# 0   2c9d57ec-4431-9c5e-2939-8f9ef6dd5cba          Bind
# 1   7eaecc1b-4337-bbf6-6ab9-04b8f06b3319        Ascent
# 2   e2ad5c54-4114-a870-9641-8ea21279579a        Icebox
# 3   d960549e-485c-e861-8d71-aa9d1aed12a2         Split
# 4   7eaecc1b-4337-bbf6-6ab9-04b8f06b3319        Ascent
# 5   2c9d57ec-4431-9c5e-2939-8f9ef6dd5cba          Bind
# 6   2c9d57ec-4431-9c5e-2939-8f9ef6dd5cba          Bind
# 7   d960549e-485c-e861-8d71-aa9d1aed12a2         Split
# 8   e2ad5c54-4114-a870-9641-8ea21279579a        Icebox
# 9   e2ad5c54-4114-a870-9641-8ea21279579a        Icebox
# 10  2fe4ed3a-450a-948b-6d6b-e89a78e680a9         Lotus
# 11  7eaecc1b-4337-bbf6-6ab9-04b8f06b3319        Ascent
#
#                          meta.version    meta.mode           meta.started_at  \
# 0    release-08.01-shipping-4-2228372  Competitive  2024-01-24T09:11:00.108Z
# 1    release-08.01-shipping-4-2228372  Competitive  2024-01-24T08:29:09.245Z
# 2    release-08.01-shipping-4-2228372  Competitive  2024-01-24T06:51:31.490Z
# 3   release-08.00-shipping-14-2191955  Competitive  2024-01-22T09:07:32.511Z
# 4   release-08.00-shipping-14-2191955  Competitive  2024-01-22T07:41:10.203Z
# 5   release-08.00-shipping-14-2191955  Competitive  2024-01-21T15:47:00.802Z
# 6   release-08.00-shipping-14-2191955  Competitive  2024-01-21T11:28:38.333Z
# 7   release-08.00-shipping-14-2191955  Competitive  2024-01-21T10:54:44.398Z
# 8   release-08.00-shipping-14-2191955  Competitive  2024-01-21T10:15:00.875Z
# 9   release-08.00-shipping-14-2191955  Competitive  2024-01-21T07:24:39.253Z
# 10   release-07.03-shipping-11-953184  Competitive  2023-08-16T15:48:02.900Z
# 11   release-05.10-shipping-11-796984  Competitive  2022-11-26T05:57:43.899Z
#
#                           meta.season.id meta.season.short meta.region  \
# 0   ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 1   ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 2   ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 3   ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 4   ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 5   ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 6   ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 7   ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 8   ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 9   ec876e6c-43e8-fa63-ffc1-2e8d4db25525              e8a1          ap
# 10  0981a882-4e7d-371a-70c4-c3b4f46c504a              e7a1          ap
# 11  aca29595-40e4-01f5-3f35-b1b3d304c96e              e5a3        None
#
#    meta.cluster  ... stats.kills stats.deaths  stats.assists stats.shots.head  \
# 0        Mumbai  ...          14            8             13                8
# 1        Mumbai  ...          10           14              4                6
# 2        Mumbai  ...          15           17             15                7
# 3        Mumbai  ...           9           15              7               11
# 4        Mumbai  ...          17           19             17                7
# 5        Mumbai  ...          12           14              9                4
# 6        Mumbai  ...           9           19             11                3
# 7        Mumbai  ...           9           14              9                5
# 8        Mumbai  ...          13            9              2                5
# 9        Mumbai  ...          22           23              7               12
# 10       Mumbai  ...          14           16              7                5
# 11       Mumbai  ...          22           20              8               11
#
#    stats.shots.body  stats.shots.leg  stats.damage.made  \
# 0                56                9               2174
# 1                33               13               1924
# 2                71               18               2908
# 3                37               17               2264
# 4                50               16               3595
# 5                90                9               2727
# 6                46               11               2055
# 7                26               10               1944
# 8                64                4               2362
# 9                95               27               4417
# 10               64                8               2754
# 11               90               20               4096
#
#     stats.damage.received  teams.red  teams.blue
# 0                    2073         13           4
# 1                    2664         13          10
# 2                    3011          8          13
# 3                    2449         13           5
# 4                    3319         14          12
# 5                    2567         13          11
# 6                    3545          9          13
# 7                    2430         13           5
# 8                    1775         13           8
# 9                    4422         16          14
# 10                   3451         10          13
# 11                   3511         13          10
#
# [12 rows x 27 columns]

# %%
columns_to_drop = ['meta.map.id', 'meta.id', 'meta.version','meta.started_at' , 'meta.season.id' , 'meta.season.short' , 'stats.character.id' , 'stats.puuid' , 'stats.tier']
df = df.drop(columns=columns_to_drop, errors='ignore')
df
# Out:
#    meta.map.name    meta.mode meta.region meta.cluster stats.team  \
# 0           Bind  Competitive          ap       Mumbai        Red
# 1         Ascent  Competitive          ap       Mumbai        Red
# 2         Icebox  Competitive          ap       Mumbai        Red
# 3          Split  Competitive          ap       Mumbai       Blue
# 4         Ascent  Competitive          ap       Mumbai        Red
# 5           Bind  Competitive          ap       Mumbai        Red
# 6           Bind  Competitive          ap       Mumbai        Red
# 7          Split  Competitive          ap       Mumbai       Blue
# 8         Icebox  Competitive          ap       Mumbai        Red
# 9         Icebox  Competitive          ap       Mumbai       Blue
# 10         Lotus  Competitive          ap       Mumbai       Blue
# 11        Ascent  Competitive        None       Mumbai       Blue
#
#     stats.level stats.character.name  stats.score  stats.kills  stats.deaths  \
# 0           146            Brimstone         3876           14             8
# 1           146                 Sova         2680           10            14
# 2           146            Brimstone         4779           15            17
# 3           146            Brimstone         3157            9            15
# 4           145            Brimstone         5428           17            19
# 5           145              Killjoy         3890           12            14
# 6           145            Brimstone         3215            9            19
# 7           145            Brimstone         3119            9            14
# 8           145              Killjoy         3811           13             9
# 9           145              Killjoy         6270           22            23
# 10          109                Gekko         4123           14            16
# 11           23                 Yoru         6442           22            20
#
#     stats.assists  stats.shots.head  stats.shots.body  stats.shots.leg  \
# 0              13                 8                56                9
# 1               4                 6                33               13
# 2              15                 7                71               18
# 3               7                11                37               17
# 4              17                 7                50               16
# 5               9                 4                90                9
# 6              11                 3                46               11
# 7               9                 5                26               10
# 8               2                 5                64                4
# 9               7                12                95               27
# 10              7                 5                64                8
# 11              8                11                90               20
#
#     stats.damage.made  stats.damage.received  teams.red  teams.blue
# 0                2174                   2073         13           4
# 1                1924                   2664         13          10
# 2                2908                   3011          8          13
# 3                2264                   2449         13           5
# 4                3595                   3319         14          12
# 5                2727                   2567         13          11
# 6                2055                   3545          9          13
# 7                1944                   2430         13           5
# 8                2362                   1775         13           8
# 9                4417                   4422         16          14
# 10               2754                   3451         10          13
# 11               4096                   3511         13          10
